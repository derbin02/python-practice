# %%
print("hello derbin")
# Out:
# hello derbin

# %%
file = open("main.py","r")
content = file.read()
print(content)
# Out:
# for i in range(5):
#     print("Derbin learning Git & VS Code:", i)

# %%
file = open("if else.py","r")
content = file.read()
print=(content)

# %%
#print number no 1-5
for i in  range(1,6):
        print("number:", i)
# Out:
# number: 1
# number: 2
# number: 3
# number: 4
# number: 5

# %%
for i in range(1,11):
    if i%2 == 0:
        print(i,"is even number")
    else:
        print(i, "is odd number")
# Out:
# 1 is odd number
# 2 is even number
# 3 is odd number
# 4 is even number
# 5 is odd number
# 6 is even number
# 7 is odd number
# 8 is even number
# 9 is odd number
# 10 is even number

# %%
for i in range(1, 21):
    if i%3 == 0:
        print(i, "is dividable by 3")
    else:
        print("not dividable")
# Out:
# not dividable
# not dividable
# 3 is dividable by 3
# not dividable
# not dividable
# 6 is dividable by 3
# not dividable
# not dividable
# 9 is dividable by 3
# not dividable
# not dividable
# 12 is dividable by 3
# not dividable
# not dividable
# 15 is dividable by 3
# not dividable
# not dividable
# 18 is dividable by 3
# not dividable
# not dividable

# %%
i-1
while i<=6:
    print("number:",i)
    i+=1
# Out:
# number: 0
# number: 1
# number: 2
# number: 3
# number: 4
# number: 5
# number: 6

# %%
dirty_cloths=3

while dirty_cloths > 0: 
        print("cloth is washing..")
        dirty_cloths-=1
print("All cloths are washed")
# Out:
# cloth is washing..
# cloth is washing..
# cloth is washing..
# All cloths are washed

# %%
pasword=""

while password!= "derbin123":
    password= input("Enter password: ")

print("successfully login")
# Out:
# successfully login
